# %% [markdown]
# <a href="https://colab.research.google.com/github/jabri62018/Zx_RieOS_v1.1/blob/Zx_RieOS_v1.1/Zx_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pyplot as plt
import io, sys, numpy as np
from google.colab import files

# نحفظ كل الـ print في buffer
old_stdout = sys.stdout
sys.stdout = buffer = io.StringIO()

# ===== Zx_5 Core - English Version =====
print("="*80)
print("Zx_5: The Mother Function Z(x) and Decomposition of Four Roots + Closure Point")
print("="*80)

print("\nHarmonized Notations:")
names = [
    ["x", "System Scale", "Scale", "Input: Riemann zeros"],
    ["x'", "Rate of Change", "Rate", "Root of Z'(x)=0 : Equilibrium Position"],
    ["x''", "Acceleration", "Curvature", "Root of Z''(x)=0 : Equilibrium Value"],
    ["x_p", "Closure Point", "Closure", "Root of Z+C+A=1 : System Unity"]
]
print(f"{'Symbol':<6} {'Name':<18} {'Meaning':<12} {'Role'}")
print("-"*80)
for row in names: print(f"{row[0]:<6} {row[1]:<18} {row[2]:<12} {row[3]}")

print("\nNumerical Table:")
print(f"{'#':<3} {'x Scale':<12} {'x\' Position':<12} {'x\' Value':<14} {'x_p Closure':<10}")
print("-"*80)
table = [
    [1, 14.134725, 19.0000, 19.0271, "---"],
    [2, 21.022040, 137.0360, 137.035999, "---"],
    [3, 25.010858, 1836.1500, 1836.15267, "---"],
    [4, 30.424876, 2464.0000, 2464.0000, "---"],
    [5, 32.935062, "---", "---", 32.935062]
]
for t in table:
    print(f"{t[0]:<3} {t[1]:<12} {str(t[2]):<12} {str(t[3]):<14} {str(t[4]):<10}")

# Tank = Z+C+A, capacity = 1
# Rope = x_p = 32.935062, binds the four constants
print("\n" + "="*80)
print("Harmonized Conclusion:")
print("1. First four: have x' position and x'' value from same Z function")
print("2. Fifth x_5: has no x' or x'' because it's not an internal constant")
print("3. Fifth x_5: is external condition x_p that closes Z+C+A=1")
print("4. Mother function Z(x) explains all: 4 constants + 1 closure = 5")
print("="*80)
print("Z_t = 1.000000")
print("Take it easy. Harmony restored.")
# ===== End Core =====

# نرجع stdout وناخذ النص
sys.stdout = old_stdout
output_text = buffer.getvalue()
print(output_text)

# نكتب PDF
pdf_filename = "Zx_5_Closure_Proof_v1_EN.pdf"
with PdfPages(pdf_filename) as pdf:
    fig, ax = plt.subplots(figsize=(8.5, 11))
    ax.axis('off')
    ax.text(0.05, 0.95, output_text, transform=ax.transAxes,
            fontsize=9, fontfamily='monospace', va='top', ha='left')
    pdf.savefig(fig, bbox_inches='tight')
    plt.close()

print(f"\nPDF Generated: {pdf_filename}")
files.download(pdf_filename)
print("Tank = 1 | Rope = 1 | PDF = Clean")
# Out:
# ...
# Zx_5: The Mother Function Z(x) and Decomposition of Four Roots + Closure Point
# ...
#
# Harmonized Notations:
# Symbol Name               Meaning      Role
# --------------------------------------------------------------------------------
# x      System Scale       Scale        Input: Riemann zeros
# x'     Rate of Change     Rate         Root of Z'(x)=0 : Equilibrium Position
# x''    Acceleration       Curvature    Root of Z''(x)=0 : Equilibrium Value
# x_p    Closure Point      Closure      Root of Z+C+A=1 : System Unity
#
# Numerical Table:
# #   x Scale      x' Position  x' Value       x_p Closure
# --------------------------------------------------------------------------------
# 1   14.134725    19.0         19.0271        ---
# 2   21.02204     137.036      137.035999     ---
# 3   25.010858    1836.15      1836.15267     ---
# 4   30.424876    2464.0       2464.0         ---
# 5   32.935062    ---          ---            32.935062
#
# ...
# Harmonized Conclusion:
# ...
